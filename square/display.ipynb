# %%
import numpy as np
import torch 
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable

gamma1 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin1_all.npz")
proton1 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin1_all.npz")

gamma2 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin2_all.npz")
proton2 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin2_all.npz")

gamma3 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin3_all.npz")
proton3 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin3_all.npz")

gamma4 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin4_all.npz")
proton4 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin4_all.npz")

gamma5 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin5_all.npz")
proton5 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin5_all.npz")

gamma6 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin6_all.npz")
proton6 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin6_all.npz")

gamma7 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin7_all.npz")
proton7 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin7_all.npz")

gamma8 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin8_all.npz")
proton8 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin8_all.npz")

gamma9 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/gamma_energy_bin9_all.npz")
proton9 = np.load("/home/jua/corsika/run/energy_var/npz/square/bin/proton_energy_bin9_all.npz")



nBin = 9

gim = gamma9['image']
pim = proton9['image']

gim = torch.tensor(gim).float()
pim = torch.tensor(pim).float()

# %%
def Draw(image, time, particle, nbin, upperlower):
    x = []
    y = []
    c = []
    s = []

    for i in range(51):
        for j in range(51):
            if image[i][j]!=0:
                x.append(i*5-125)
                y.append(j*5-125)
                c.append(time[i][j])
                s.append(image[i][j])
    fig, ax = plt.subplots(figsize=(13,10))
    
    # Draw detertor
    
    #tx = range(-125,125,1)
    #ty = range(-125,125,1)
    #tx,ty = np.meshgrid(tx,ty)
    #ax.scatter(tx,ty,c='black',marker='o',s=0.1)

    ax.set_title("{}, ({} pmt)".format(particle,upperlower),fontsize=40,y=1.05)
    ax.set_xlabel("unit [m]",fontsize=30,x=0.9)
    ax.set_ylabel("unit [m]",fontsize=30,labelpad=-20,y=0.87)
    ax.tick_params(axis='both',labelsize=30)

    im = ax.scatter(x,y,cmap='jet', s=s,c=c)
    
    cbar = fig.colorbar(im)
    cbar.ax.tick_params(labelsize=30)
    cbar.set_label("time scale [ns]", rotation=270, fontsize=30, labelpad=40, y=0.8)
    fig.savefig("plots/image/{}_{}_Bin_{}.png".format(particle,upperlower,nbin))
    plt.show()

# %%
image1 = np.array(pim[0][0])
time1 = np.array(pim[0][1])
image2 = np.array(pim[0][2])
time2 = np.array(pim[0][3])
Draw(image1,time1,'proton',nBin,'upper')
Draw(image2,time2,'proton',nBin,'lower')

# %%
image1 = np.array(gim[0][0])
time1 = np.array(gim[0][1])
image2 = np.array(gim[0][2])
time2 = np.array(gim[0][3])
Draw(image1,time1,'gamma',nBin,'upper')
Draw(image2,time2,'gamma',nBin,'lower')
